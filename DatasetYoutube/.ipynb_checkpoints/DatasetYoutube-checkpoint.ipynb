# %%
import pandas as pd

# %%
#
data_y=pd.read_csv('USvideos.csv')
len(data_y.columns)
# Out:
# 16

# %%
#
data_y.tail(5)
# Out:
#           video_id trending_date  \
# 23357  pH7VfJDq7f4      18.12.03
# 23358  hV-yHbbrKRA      18.12.03
# 23359  CwKp6Xhy3_4      18.12.03
# 23360  vQiiNGllGQo      18.12.03
# 23361  2afSbqlp5HU      18.12.03
#
#                                                title            channel_title  \
# 23357                            Why Bridges Move...    Practical Engineering
# 23358                  Macaroni - A Recipe From 1784                Townsends
# 23359                       Chris Young - Hangin' On           ChrisYoungVEVO
# 23360  Elderly man making sure his dog won't get wet  Rock me, Joey Santiago.
# 23361     How to speak like Black Panther - BBC News                 BBC News
#
#        category_id              publish_time  \
# 23357           27  2018-02-27T12:00:08.000Z
# 23358           27  2018-02-26T21:23:39.000Z
# 23359           10  2018-02-26T08:00:02.000Z
# 23360           15  2018-02-26T11:09:32.000Z
# 23361            1  2018-02-27T12:26:49.000Z
#
# ...

# %%
#
data_y.drop(['thumbnail_link','video_id','trending_date','publish_time','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed'],axis=1,inplace=True)
print(len(data_y.columns))
data_y.columns
# Out:
# 9
# Index(['title', 'channel_title', 'category_id', 'tags', 'views', 'likes',
#        'dislikes', 'comment_count', 'description'],
#       dtype='object')

# %%
len(data_y.columns)#
# Out:
# 9

# %%
len(data_y.index)#
# Out:
# 23362

# %%
#Like sayı
data_y['likes'].mean()
# Out:
# 45085.35972947522

# %%
#Dislike
data_y['dislikes'].mean()
# Out:
# 2809.7094426847016

# %%
#
data_y[data_y['views']==data_y['views'].max()]['title']
# Out:
# 6181    YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# Name: title, dtype: object

# %%
#
data_y[data_y['views']==data_y['views'].min()]
# Out:
#                                                   title channel_title  \
# 14335  1 dead, others injured after Ky. school shooting         Newsy
#
#        category_id                                               tags  views  \
# 14335           25  shooting|"kentucky"|"breaking news"|"u.s. news...    549
#
#        likes  dislikes  comment_count  \
# 14335      9         0              5
#
#                                              description
# 14335  Kentucky Gov. Matt Bevin confirmed there was a...

# %%
#
pd.DataFrame(data_y.groupby('category_id')['comment_count'].mean())
# Out:
#              comment_count
# category_id
# 1              6003.651813
# 2              1730.438235
# 10            10383.559418
# 15             2474.376054
# 17             3256.199515
# 19             1833.011450
# 20             7578.383607
# 22             4491.865854
# 23             5432.868554
# 24             7178.388176
# 25             1523.749869
# 26             4992.165997
# 27             2143.574850
# 28             3350.945159
# 29           100071.562500
# 43             1340.375000

# %%
#
# def func(data):
#     for x in data['category_id'].unique():
#        return len(data[data['category_id']==x].index)
    
# pd.DataFrame(data_y.groupby('category_id').apply(func))

data_y['category_id'].value_counts()
# Out:
# category_id
# 24    5379
# 10    3366
# 26    2241
# 23    1978
# 25    1907
# 22    1886
# 28    1477
# 1     1324
# 17    1238
# 27    1002
# 15     593
# 2      340
# 20     305
# 19     262
# 29      48
# 43      16
# Name: count, dtype: int64

# %%
#
data_y['titel_len']=data_y['title'].apply(len)
data_y
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
#
def tagsCount(data):
        return len(str(data).split('|"'))
data_y['tags_len']=data_y['tags'].apply(tagsCount)

# type(data_y['tags'][1])#=>str
data_y
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
#
data_y.sort_values('likes',ascending=False)
# Out:
#                                                    title        channel_title  \
# 6181   YouTube Rewind: The Shape of 2017 | #YouTubeRe...    YouTube Spotlight
# 5935   YouTube Rewind: The Shape of 2017 | #YouTubeRe...    YouTube Spotlight
# 5699   YouTube Rewind: The Shape of 2017 | #YouTubeRe...    YouTube Spotlight
# 5452   YouTube Rewind: The Shape of 2017 | #YouTubeRe...    YouTube Spotlight
# 3581   BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...              ibighit
# ...                                                  ...                  ...
# 7976   Dan Le Batard Breaks Down On Air After John Sk...     Sports Lovers n1
# 18648  Paris Hilton - “I Need You” (Official Music Vi...         Paris Hilton
# 19304  Paris Hilton - “I Need You” (Official Music Vi...         Paris Hilton
# 15334          Vince McMahon's Major Sports Announcement  Alpha Entertainment
# 17496                                    To Our Daughter         Kylie Jenner
#
# ...

# %%
# def sort():
